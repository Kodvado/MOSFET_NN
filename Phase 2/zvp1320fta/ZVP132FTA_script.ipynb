# %%
import numpy as np
import tensorflow as tf
from tensorflow import keras
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler
import matplotlib.pyplot as plt

# Load the dataset
file_path = "Ouput 0-6V Gate 0-3.2V Step -0.2.txt"
data = np.loadtxt(file_path, usecols=(0, 1))  # Ignore third column

# Extract VDS and ID
VDS = data[:, 0]  # First column is VDS
ID = data[:, 1]  # Second column is ID

# Generate VGS values based on dataset steps
VGS_values = np.arange(0, 3.4, 0.2)  # VGS from 0V to 3.2V with -0.2V steps
num_VGS = len(VGS_values)
num_points_per_sweep = len(VDS) // num_VGS

# Reshape VDS and ID correctly
VDS_reshaped = VDS[:num_points_per_sweep]  # Take first sweep for VDS reference
ID_reshaped = ID.reshape(num_VGS, num_points_per_sweep)

# Generate (VGS, VDS) pairs as input features
X = np.array([[VGS, vds] for VGS in VGS_values for vds in VDS_reshaped])
y = ID  # Target (ID values)

# Normalize input features and output target
scaler_X = MinMaxScaler()
scaler_y = MinMaxScaler()

scaler_X.fit(np.array([[min(VGS_values), 0], [max(VGS_values), max(VDS)]]))  # Normalize within dataset range
scaler_y.fit(y.reshape(-1, 1))  # Normalize output (ID)

X_scaled = scaler_X.transform(X)
y_scaled = scaler_y.transform(y.reshape(-1, 1))

# Split data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X_scaled, y_scaled, test_size=0.2, random_state=42)

# Define a new neural network model
model = keras.Sequential([
    keras.layers.Dense(128, activation='relu', input_shape=(2,)),  # Two input features: VGS, VDS
    keras.layers.Dense(128, activation='relu'),
    keras.layers.Dense(1)  # Single output: ID
])

# Compile model
model.compile(optimizer='adam', loss='mse', metrics=['mae'])

# Train the model
history = model.fit(X_train, y_train, epochs=200, batch_size=16, validation_data=(X_test, y_test), verbose=1)

# Save the trained model
model.save("/mnt/data/mosfet_model_6V.h5")
print("Model saved as mosfet_model_6V.h5")

# Evaluate model performance
loss, mae = model.evaluate(X_test, y_test)
print(f"Test MAE: {mae:.6f}")

# Plot training & validation loss
plt.figure(figsize=(8, 6))
plt.plot(history.history['loss'], label="Train Loss")
plt.plot(history.history['val_loss'], label="Validation Loss")
plt.xlabel("Epochs")
plt.ylabel("Loss (MSE)")
plt.title("Training & Validation Loss Over Epochs")
plt.legend()
plt.grid(True)
plt.show()
# Out:
# Epoch 1/200
# 52/52 [==============================] - 1s 7ms/step - loss: 0.2852 - mae: 0.4176 - val_loss: 0.1037 - val_mae: 0.2505
# Epoch 2/200
# 52/52 [==============================] - 0s 4ms/step - loss: 0.0912 - mae: 0.2226 - val_loss: 0.0483 - val_mae: 0.1726
# Epoch 3/200
# 52/52 [==============================] - 0s 3ms/step - loss: 0.0468 - mae: 0.1497 - val_loss: 0.0273 - val_mae: 0.1067
# Epoch 4/200
# 52/52 [==============================] - 0s 3ms/step - loss: 0.0345 - mae: 0.1257 - val_loss: 0.0271 - val_mae: 0.1039
# Epoch 5/200
# 52/52 [==============================] - 0s 3ms/step - loss: 0.0338 - mae: 0.1207 - val_loss: 0.0286 - val_mae: 0.1278
# Epoch 6/200
# 52/52 [==============================] - 0s 3ms/step - loss: 0.0345 - mae: 0.1293 - val_loss: 0.0255 - val_mae: 0.1083
# Epoch 7/200
# 52/52 [==============================] - 0s 3ms/step - loss: 0.0290 - mae: 0.1121 - val_loss: 0.0197 - val_mae: 0.0855
# Epoch 8/200
# 52/52 [==============================] - 0s 2ms/step - loss: 0.0274 - mae: 0.1073 - val_loss: 0.0269 - val_mae: 0.1243
# Epoch 9/200
# 52/52 [==============================] - 0s 3ms/step - loss: 0.0293 - mae: 0.1185 - val_loss: 0.0286 - val_mae: 0.1107
# Epoch 10/200
# 52/52 [==============================] - 0s 3ms/step - loss: 0.0272 - mae: 0.1064 - val_loss: 0.0166 - val_mae: 0.0799
# Epoch 11/200
# 52/52 [==============================] - 0s 3ms/step - loss: 0.0221 - mae: 0.0943 - val_loss: 0.0185 - val_mae: 0.1016
# Epoch 12/200
# 52/52 [==============================] - 0s 3ms/step - loss: 0.0235 - mae: 0.1003 - val_loss: 0.0164 - val_mae: 0.0730
# Epoch 13/200
# 52/52 [==============================] - 0s 2ms/step - loss: 0.0203 - mae: 0.0901 - val_loss: 0.0142 - val_mae: 0.0778
# Epoch 14/200
# 52/52 [==============================] - 0s 3ms/step - loss: 0.0215 - mae: 0.0973 - val_loss: 0.0181 - val_mae: 0.1057
# Epoch 15/200
# 52/52 [==============================] - 0s 3ms/step - loss: 0.0202 - mae: 0.0982 - val_loss: 0.0119 - val_mae: 0.0672
# Epoch 16/200
# 52/52 [==============================] - 0s 3ms/step - loss: 0.0157 - mae: 0.0778 - val_loss: 0.0308 - val_mae: 0.1416
# Epoch 17/200
# 52/52 [==============================] - 0s 2ms/step - loss: 0.0152 - mae: 0.0765 - val_loss: 0.0083 - val_mae: 0.0436
# Epoch 18/200
# 52/52 [==============================] - 0s 2ms/step - loss: 0.0130 - mae: 0.0645 - val_loss: 0.0094 - val_mae: 0.0652
# Epoch 19/200
# 52/52 [==============================] - 0s 3ms/step - loss: 0.0125 - mae: 0.0705 - val_loss: 0.0097 - val_mae: 0.0717
# Epoch 20/200
# 52/52 [==============================] - 0s 3ms/step - loss: 0.0119 - mae: 0.0685 - val_loss: 0.0070 - val_mae: 0.0510
# Epoch 21/200
# 52/52 [==============================] - 0s 2ms/step - loss: 0.0108 - mae: 0.0662 - val_loss: 0.0059 - val_mae: 0.0421
# Epoch 22/200
# 52/52 [==============================] - 0s 3ms/step - loss: 0.0114 - mae: 0.0691 - val_loss: 0.0059 - val_mae: 0.0421
# Epoch 23/200
# 52/52 [==============================] - 0s 3ms/step - loss: 0.0088 - mae: 0.0590 - val_loss: 0.0052 - val_mae: 0.0415
# Epoch 24/200
# 52/52 [==============================] - 0s 3ms/step - loss: 0.0077 - mae: 0.0517 - val_loss: 0.0041 - val_mae: 0.0330
# Epoch 25/200
# 52/52 [==============================] - 0s 3ms/step - loss: 0.0079 - mae: 0.0533 - val_loss: 0.0036 - val_mae: 0.0270
# Epoch 26/200
# 52/52 [==============================] - 0s 2ms/step - loss: 0.0076 - mae: 0.0553 - val_loss: 0.0033 - val_mae: 0.0270
# Epoch 27/200
# 52/52 [==============================] - 0s 2ms/step - loss: 0.0063 - mae: 0.0486 - val_loss: 0.0045 - val_mae: 0.0524
# Epoch 28/200
# 52/52 [==============================] - 0s 2ms/step - loss: 0.0060 - mae: 0.0483 - val_loss: 0.0063 - val_mae: 0.0379
# Epoch 29/200
# 52/52 [==============================] - 0s 2ms/step - loss: 0.0061 - mae: 0.0455 - val_loss: 0.0030 - val_mae: 0.0277
# Epoch 30/200
# 52/52 [==============================] - 0s 2ms/step - loss: 0.0082 - mae: 0.0566 - val_loss: 0.0026 - val_mae: 0.0291
# Epoch 31/200
# 52/52 [==============================] - 0s 3ms/step - loss: 0.0058 - mae: 0.0470 - val_loss: 0.0038 - val_mae: 0.0468
# Epoch 32/200
# 52/52 [==============================] - 0s 3ms/step - loss: 0.0037 - mae: 0.0367 - val_loss: 0.0019 - val_mae: 0.0224
# Epoch 33/200
# 52/52 [==============================] - 0s 3ms/step - loss: 0.0046 - mae: 0.0435 - val_loss: 0.0041 - val_mae: 0.0290
# Epoch 34/200
# 52/52 [==============================] - 0s 2ms/step - loss: 0.0040 - mae: 0.0364 - val_loss: 0.0030 - val_mae: 0.0233
# Epoch 35/200
# 52/52 [==============================] - 0s 2ms/step - loss: 0.0059 - mae: 0.0521 - val_loss: 0.0017 - val_mae: 0.0206
# Epoch 36/200
# 52/52 [==============================] - 0s 2ms/step - loss: 0.0032 - mae: 0.0334 - val_loss: 0.0017 - val_mae: 0.0199
# Epoch 37/200
# 52/52 [==============================] - 0s 2ms/step - loss: 0.0027 - mae: 0.0318 - val_loss: 0.0014 - val_mae: 0.0165
# Epoch 38/200
# 52/52 [==============================] - 0s 2ms/step - loss: 0.0031 - mae: 0.0358 - val_loss: 0.0013 - val_mae: 0.0187
# Epoch 39/200
# 52/52 [==============================] - 0s 2ms/step - loss: 0.0021 - mae: 0.0264 - val_loss: 0.0013 - val_mae: 0.0193
# Epoch 40/200
# 52/52 [==============================] - 0s 3ms/step - loss: 0.0021 - mae: 0.0268 - val_loss: 0.0026 - val_mae: 0.0376
# Epoch 41/200
# 52/52 [==============================] - 0s 2ms/step - loss: 0.0028 - mae: 0.0345 - val_loss: 0.0011 - val_mae: 0.0185
# Epoch 42/200
# 52/52 [==============================] - 0s 2ms/step - loss: 0.0019 - mae: 0.0251 - val_loss: 0.0010 - val_mae: 0.0185
# Epoch 43/200
# 52/52 [==============================] - 0s 2ms/step - loss: 0.0018 - mae: 0.0252 - val_loss: 8.8544e-04 - val_mae: 0.0126
# Epoch 44/200
# 52/52 [==============================] - 0s 2ms/step - loss: 0.0022 - mae: 0.0294 - val_loss: 0.0029 - val_mae: 0.0474
# Epoch 45/200
# 52/52 [==============================] - 0s 2ms/step - loss: 0.0015 - mae: 0.0215 - val_loss: 0.0010 - val_mae: 0.0234
# Epoch 46/200
# 52/52 [==============================] - 0s 3ms/step - loss: 0.0019 - mae: 0.0280 - val_loss: 0.0015 - val_mae: 0.0310
# Epoch 47/200
# 52/52 [==============================] - 0s 3ms/step - loss: 0.0018 - mae: 0.0271 - val_loss: 0.0026 - val_mae: 0.0410
# Epoch 48/200
# 52/52 [==============================] - 0s 3ms/step - loss: 0.0025 - mae: 0.0309 - val_loss: 0.0013 - val_mae: 0.0235
# Epoch 49/200
# 52/52 [==============================] - 0s 2ms/step - loss: 0.0011 - mae: 0.0197 - val_loss: 0.0011 - val_mae: 0.0159
# Epoch 50/200
# 52/52 [==============================] - 0s 2ms/step - loss: 0.0016 - mae: 0.0259 - val_loss: 6.9848e-04 - val_mae: 0.0158
# Epoch 51/200
# 52/52 [==============================] - 0s 2ms/step - loss: 7.0007e-04 - mae: 0.0141 - val_loss: 0.0011 - val_mae: 0.0271
# Epoch 52/200
# 52/52 [==============================] - 0s 3ms/step - loss: 6.9115e-04 - mae: 0.0153 - val_loss: 4.0906e-04 - val_mae: 0.0101
# Epoch 53/200
# 52/52 [==============================] - 0s 2ms/step - loss: 7.6729e-04 - mae: 0.0172 - val_loss: 3.7622e-04 - val_mae: 0.0089
# Epoch 54/200
# 52/52 [==============================] - 0s 2ms/step - loss: 9.7125e-04 - mae: 0.0212 - val_loss: 7.6876e-04 - val_mae: 0.0220
# Epoch 55/200
# 52/52 [==============================] - 0s 2ms/step - loss: 6.2548e-04 - mae: 0.0157 - val_loss: 4.5290e-04 - val_mae: 0.0162
# Epoch 56/200
# 52/52 [==============================] - 0s 3ms/step - loss: 6.2318e-04 - mae: 0.0160 - val_loss: 6.4824e-04 - val_mae: 0.0189
# Epoch 57/200
# 52/52 [==============================] - 0s 3ms/step - loss: 5.6562e-04 - mae: 0.0155 - val_loss: 1.9462e-04 - val_mae: 0.0073
# Epoch 58/200
# 52/52 [==============================] - 0s 2ms/step - loss: 6.9173e-04 - mae: 0.0165 - val_loss: 2.0766e-04 - val_mae: 0.0096
# Epoch 59/200
# 52/52 [==============================] - 0s 3ms/step - loss: 3.8136e-04 - mae: 0.0122 - val_loss: 2.2113e-04 - val_mae: 0.0080
# Epoch 60/200
# 52/52 [==============================] - 0s 3ms/step - loss: 3.9849e-04 - mae: 0.0124 - val_loss: 2.1862e-04 - val_mae: 0.0101
# Epoch 61/200
# 52/52 [==============================] - 0s 3ms/step - loss: 4.6320e-04 - mae: 0.0119 - val_loss: 0.0040 - val_mae: 0.0417
# Epoch 62/200
# 52/52 [==============================] - 0s 3ms/step - loss: 0.0013 - mae: 0.0248 - val_loss: 0.0016 - val_mae: 0.0336
# Epoch 63/200
# 52/52 [==============================] - 0s 2ms/step - loss: 0.0020 - mae: 0.0290 - val_loss: 5.9873e-04 - val_mae: 0.0199
# Epoch 64/200
# 52/52 [==============================] - 0s 3ms/step - loss: 5.5492e-04 - mae: 0.0160 - val_loss: 5.2388e-04 - val_mae: 0.0199
# Epoch 65/200
# 52/52 [==============================] - 0s 2ms/step - loss: 9.1535e-04 - mae: 0.0211 - val_loss: 8.6399e-04 - val_mae: 0.0217
# Epoch 66/200
# 52/52 [==============================] - 0s 2ms/step - loss: 0.0014 - mae: 0.0264 - val_loss: 0.0039 - val_mae: 0.0499
# Epoch 67/200
# 52/52 [==============================] - 0s 3ms/step - loss: 0.0019 - mae: 0.0294 - val_loss: 4.7879e-04 - val_mae: 0.0184
# Epoch 68/200
# 52/52 [==============================] - 0s 3ms/step - loss: 6.0362e-04 - mae: 0.0162 - val_loss: 3.3958e-04 - val_mae: 0.0114
# Epoch 69/200
# 52/52 [==============================] - 0s 3ms/step - loss: 2.7463e-04 - mae: 0.0098 - val_loss: 1.3097e-04 - val_mae: 0.0065
# Epoch 70/200
# 52/52 [==============================] - 0s 3ms/step - loss: 1.5416e-04 - mae: 0.0074 - val_loss: 1.6547e-04 - val_mae: 0.0066
# Epoch 71/200
# 52/52 [==============================] - 0s 3ms/step - loss: 1.7460e-04 - mae: 0.0080 - val_loss: 1.2951e-04 - val_mae: 0.0090
# Epoch 72/200
# 52/52 [==============================] - 0s 3ms/step - loss: 2.9676e-04 - mae: 0.0099 - val_loss: 8.7979e-04 - val_mae: 0.0270
# Epoch 73/200
# 52/52 [==============================] - 0s 3ms/step - loss: 7.3197e-04 - mae: 0.0179 - val_loss: 9.7304e-04 - val_mae: 0.0280
# Epoch 74/200
# 52/52 [==============================] - 0s 2ms/step - loss: 4.5069e-04 - mae: 0.0140 - val_loss: 1.3275e-04 - val_mae: 0.0067
# Epoch 75/200
# 52/52 [==============================] - 0s 2ms/step - loss: 2.6514e-04 - mae: 0.0117 - val_loss: 8.8156e-05 - val_mae: 0.0063
# Epoch 76/200
# 52/52 [==============================] - 0s 2ms/step - loss: 1.5379e-04 - mae: 0.0079 - val_loss: 1.4424e-04 - val_mae: 0.0082
# Epoch 77/200
# 52/52 [==============================] - 0s 2ms/step - loss: 1.4397e-04 - mae: 0.0079 - val_loss: 6.4161e-05 - val_mae: 0.0042
# Epoch 78/200
# 52/52 [==============================] - 0s 2ms/step - loss: 2.6042e-04 - mae: 0.0108 - val_loss: 1.7963e-04 - val_mae: 0.0101
# Epoch 79/200
# 52/52 [==============================] - 0s 3ms/step - loss: 2.0516e-04 - mae: 0.0095 - val_loss: 1.5546e-04 - val_mae: 0.0105
# Epoch 80/200
# 52/52 [==============================] - 0s 3ms/step - loss: 5.2132e-04 - mae: 0.0156 - val_loss: 3.2195e-04 - val_mae: 0.0097
# Epoch 81/200
# 52/52 [==============================] - 0s 2ms/step - loss: 3.5557e-04 - mae: 0.0131 - val_loss: 5.5953e-05 - val_mae: 0.0055
# Epoch 82/200
# 52/52 [==============================] - 0s 2ms/step - loss: 5.4126e-04 - mae: 0.0149 - val_loss: 3.7146e-04 - val_mae: 0.0101
# Epoch 83/200
# 52/52 [==============================] - 0s 3ms/step - loss: 0.0027 - mae: 0.0369 - val_loss: 5.4068e-04 - val_mae: 0.0118
# Epoch 84/200
# 52/52 [==============================] - 0s 3ms/step - loss: 7.9856e-04 - mae: 0.0182 - val_loss: 1.1614e-04 - val_mae: 0.0077
# Epoch 85/200
# 52/52 [==============================] - 0s 3ms/step - loss: 0.0016 - mae: 0.0281 - val_loss: 4.1939e-04 - val_mae: 0.0145
# Epoch 86/200
# 52/52 [==============================] - 0s 3ms/step - loss: 0.0013 - mae: 0.0250 - val_loss: 0.0017 - val_mae: 0.0350
# Epoch 87/200
# 52/52 [==============================] - 0s 3ms/step - loss: 0.0019 - mae: 0.0305 - val_loss: 4.9897e-04 - val_mae: 0.0201
# Epoch 88/200
# 52/52 [==============================] - 0s 4ms/step - loss: 3.5155e-04 - mae: 0.0130 - val_loss: 3.8875e-04 - val_mae: 0.0116
# Epoch 89/200
# 52/52 [==============================] - 0s 3ms/step - loss: 1.5568e-04 - mae: 0.0087 - val_loss: 9.9113e-05 - val_mae: 0.0051
# Epoch 90/200
# 52/52 [==============================] - 0s 2ms/step - loss: 1.2033e-04 - mae: 0.0072 - val_loss: 8.2509e-05 - val_mae: 0.0054
# Epoch 91/200
# 52/52 [==============================] - 0s 2ms/step - loss: 1.5606e-04 - mae: 0.0087 - val_loss: 1.2241e-04 - val_mae: 0.0055
# Epoch 92/200
# 52/52 [==============================] - 0s 3ms/step - loss: 1.4274e-04 - mae: 0.0078 - val_loss: 2.0163e-04 - val_mae: 0.0094
# Epoch 93/200
# 52/52 [==============================] - 0s 3ms/step - loss: 1.0517e-04 - mae: 0.0072 - val_loss: 3.7768e-05 - val_mae: 0.0048
# Epoch 94/200
# 52/52 [==============================] - 0s 3ms/step - loss: 9.4524e-04 - mae: 0.0188 - val_loss: 0.0021 - val_mae: 0.0401
# Epoch 95/200
# 52/52 [==============================] - 0s 3ms/step - loss: 0.0077 - mae: 0.0651 - val_loss: 0.0018 - val_mae: 0.0304
# Epoch 96/200
# 52/52 [==============================] - 0s 3ms/step - loss: 0.0018 - mae: 0.0287 - val_loss: 5.8832e-04 - val_mae: 0.0180
# Epoch 97/200
# 52/52 [==============================] - 0s 2ms/step - loss: 0.0013 - mae: 0.0239 - val_loss: 7.6761e-04 - val_mae: 0.0225
# Epoch 98/200
# 52/52 [==============================] - 0s 3ms/step - loss: 2.1944e-04 - mae: 0.0094 - val_loss: 8.3657e-05 - val_mae: 0.0052
# Epoch 99/200
# 52/52 [==============================] - 0s 2ms/step - loss: 4.7824e-04 - mae: 0.0152 - val_loss: 4.1798e-04 - val_mae: 0.0115
# Epoch 100/200
# 52/52 [==============================] - 0s 3ms/step - loss: 2.8340e-04 - mae: 0.0110 - val_loss: 1.2828e-04 - val_mae: 0.0069
# Epoch 101/200
# 52/52 [==============================] - 0s 2ms/step - loss: 1.7483e-04 - mae: 0.0077 - val_loss: 4.0334e-04 - val_mae: 0.0175
# Epoch 102/200
# 52/52 [==============================] - 0s 3ms/step - loss: 5.1795e-04 - mae: 0.0158 - val_loss: 8.5716e-04 - val_mae: 0.0276
# Epoch 103/200
# 52/52 [==============================] - 0s 3ms/step - loss: 0.0011 - mae: 0.0191 - val_loss: 0.0018 - val_mae: 0.0334
# Epoch 104/200
# 52/52 [==============================] - 0s 2ms/step - loss: 6.7612e-04 - mae: 0.0176 - val_loss: 3.7640e-04 - val_mae: 0.0164
# Epoch 105/200
# 52/52 [==============================] - 0s 2ms/step - loss: 3.0462e-04 - mae: 0.0113 - val_loss: 2.1515e-04 - val_mae: 0.0091
# Epoch 106/200
# 52/52 [==============================] - 0s 2ms/step - loss: 2.0702e-04 - mae: 0.0093 - val_loss: 7.9050e-05 - val_mae: 0.0064
# Epoch 107/200
# 52/52 [==============================] - 0s 3ms/step - loss: 1.1671e-04 - mae: 0.0066 - val_loss: 7.2800e-05 - val_mae: 0.0049
# Epoch 108/200
# 52/52 [==============================] - 0s 3ms/step - loss: 2.0816e-04 - mae: 0.0088 - val_loss: 0.0010 - val_mae: 0.0306
# Epoch 109/200
# 52/52 [==============================] - 0s 2ms/step - loss: 3.6545e-04 - mae: 0.0132 - val_loss: 4.5936e-05 - val_mae: 0.0054
# Epoch 110/200
# 52/52 [==============================] - 0s 3ms/step - loss: 1.8687e-04 - mae: 0.0093 - val_loss: 3.7148e-05 - val_mae: 0.0040
# Epoch 111/200
# 52/52 [==============================] - 0s 3ms/step - loss: 1.8270e-04 - mae: 0.0077 - val_loss: 4.8257e-04 - val_mae: 0.0199
# Epoch 112/200
# 52/52 [==============================] - 0s 3ms/step - loss: 8.2267e-04 - mae: 0.0201 - val_loss: 2.4763e-04 - val_mae: 0.0115
# Epoch 113/200
# 52/52 [==============================] - 0s 3ms/step - loss: 0.0017 - mae: 0.0287 - val_loss: 4.9564e-04 - val_mae: 0.0170
# Epoch 114/200
# 52/52 [==============================] - 0s 4ms/step - loss: 7.4656e-04 - mae: 0.0186 - val_loss: 2.6434e-04 - val_mae: 0.0114
# Epoch 115/200
# 52/52 [==============================] - 0s 3ms/step - loss: 1.3682e-04 - mae: 0.0077 - val_loss: 1.4523e-04 - val_mae: 0.0098
# Epoch 116/200
# 52/52 [==============================] - 0s 2ms/step - loss: 6.2800e-05 - mae: 0.0052 - val_loss: 1.0009e-04 - val_mae: 0.0083
# Epoch 117/200
# 52/52 [==============================] - 0s 3ms/step - loss: 1.3872e-04 - mae: 0.0080 - val_loss: 1.8777e-04 - val_mae: 0.0122
# Epoch 118/200
# 52/52 [==============================] - 0s 3ms/step - loss: 1.1069e-04 - mae: 0.0077 - val_loss: 5.6637e-05 - val_mae: 0.0051
# Epoch 119/200
# 52/52 [==============================] - 0s 3ms/step - loss: 6.6603e-04 - mae: 0.0167 - val_loss: 4.6255e-04 - val_mae: 0.0155
# Epoch 120/200
# 52/52 [==============================] - 0s 2ms/step - loss: 2.8967e-04 - mae: 0.0104 - val_loss: 1.2468e-04 - val_mae: 0.0073
# Epoch 121/200
# 52/52 [==============================] - 0s 3ms/step - loss: 1.4826e-04 - mae: 0.0083 - val_loss: 1.2412e-04 - val_mae: 0.0073
# Epoch 122/200
# 52/52 [==============================] - 0s 3ms/step - loss: 3.1645e-04 - mae: 0.0114 - val_loss: 2.7735e-04 - val_mae: 0.0135
# Epoch 123/200
# 52/52 [==============================] - 0s 3ms/step - loss: 6.8734e-04 - mae: 0.0178 - val_loss: 0.0036 - val_mae: 0.0295
# Epoch 124/200
# 52/52 [==============================] - 0s 3ms/step - loss: 0.0072 - mae: 0.0543 - val_loss: 0.0075 - val_mae: 0.0821
# Epoch 125/200
# 52/52 [==============================] - 0s 3ms/step - loss: 0.0015 - mae: 0.0254 - val_loss: 3.9394e-04 - val_mae: 0.0162
# Epoch 126/200
# 52/52 [==============================] - 0s 2ms/step - loss: 0.0011 - mae: 0.0246 - val_loss: 2.8134e-04 - val_mae: 0.0096
# Epoch 127/200
# 52/52 [==============================] - 0s 2ms/step - loss: 3.5105e-04 - mae: 0.0119 - val_loss: 1.2440e-04 - val_mae: 0.0075
# Epoch 128/200
# 52/52 [==============================] - 0s 2ms/step - loss: 8.3248e-04 - mae: 0.0170 - val_loss: 2.0076e-04 - val_mae: 0.0110
# Epoch 129/200
# 52/52 [==============================] - 0s 2ms/step - loss: 5.7946e-04 - mae: 0.0155 - val_loss: 5.7778e-04 - val_mae: 0.0106
# Epoch 130/200
# 52/52 [==============================] - 0s 2ms/step - loss: 4.4672e-04 - mae: 0.0142 - val_loss: 3.3706e-04 - val_mae: 0.0150
# Epoch 131/200
# 52/52 [==============================] - 0s 3ms/step - loss: 1.9619e-04 - mae: 0.0087 - val_loss: 1.4467e-04 - val_mae: 0.0102
# Epoch 132/200
# 52/52 [==============================] - 0s 3ms/step - loss: 1.6038e-04 - mae: 0.0082 - val_loss: 8.2485e-05 - val_mae: 0.0050
# Epoch 133/200
# 52/52 [==============================] - 0s 3ms/step - loss: 7.6434e-05 - mae: 0.0055 - val_loss: 1.8317e-04 - val_mae: 0.0078
# Epoch 134/200
# 52/52 [==============================] - 0s 3ms/step - loss: 2.2590e-04 - mae: 0.0104 - val_loss: 6.0356e-04 - val_mae: 0.0107
# Epoch 135/200
# 52/52 [==============================] - 0s 2ms/step - loss: 4.4827e-04 - mae: 0.0138 - val_loss: 1.3544e-04 - val_mae: 0.0062
# Epoch 136/200
# 52/52 [==============================] - 0s 3ms/step - loss: 3.2193e-04 - mae: 0.0119 - val_loss: 1.0171e-04 - val_mae: 0.0072
# Epoch 137/200
# 52/52 [==============================] - 0s 2ms/step - loss: 9.1142e-05 - mae: 0.0059 - val_loss: 1.1485e-04 - val_mae: 0.0081
# Epoch 138/200
# 52/52 [==============================] - 0s 3ms/step - loss: 1.5383e-04 - mae: 0.0079 - val_loss: 2.3435e-04 - val_mae: 0.0118
# Epoch 139/200
# 52/52 [==============================] - 0s 3ms/step - loss: 1.9408e-04 - mae: 0.0092 - val_loss: 2.6029e-04 - val_mae: 0.0127
# Epoch 140/200
# 52/52 [==============================] - 0s 3ms/step - loss: 1.3757e-04 - mae: 0.0074 - val_loss: 6.3071e-05 - val_mae: 0.0050
# Epoch 141/200
# 52/52 [==============================] - 0s 2ms/step - loss: 1.6437e-04 - mae: 0.0084 - val_loss: 8.7569e-04 - val_mae: 0.0141
# Epoch 142/200
# 52/52 [==============================] - 0s 2ms/step - loss: 0.0012 - mae: 0.0217 - val_loss: 0.0040 - val_mae: 0.0528
# Epoch 143/200
# 52/52 [==============================] - 0s 2ms/step - loss: 7.4845e-04 - mae: 0.0153 - val_loss: 7.7588e-04 - val_mae: 0.0221
# Epoch 144/200
# 52/52 [==============================] - 0s 2ms/step - loss: 8.3566e-04 - mae: 0.0202 - val_loss: 3.4839e-04 - val_mae: 0.0119
# Epoch 145/200
# 52/52 [==============================] - 0s 3ms/step - loss: 0.0017 - mae: 0.0267 - val_loss: 8.8468e-04 - val_mae: 0.0244
# Epoch 146/200
# 52/52 [==============================] - 0s 3ms/step - loss: 2.2432e-04 - mae: 0.0099 - val_loss: 2.4489e-04 - val_mae: 0.0071
# Epoch 147/200
# 52/52 [==============================] - 0s 3ms/step - loss: 1.6300e-04 - mae: 0.0093 - val_loss: 2.5355e-04 - val_mae: 0.0108
# Epoch 148/200
# 52/52 [==============================] - 0s 3ms/step - loss: 5.7374e-04 - mae: 0.0153 - val_loss: 2.0613e-04 - val_mae: 0.0126
# Epoch 149/200
# 52/52 [==============================] - 0s 2ms/step - loss: 8.5346e-04 - mae: 0.0222 - val_loss: 2.0746e-04 - val_mae: 0.0078
# Epoch 150/200
# 52/52 [==============================] - 0s 3ms/step - loss: 1.8747e-04 - mae: 0.0083 - val_loss: 1.5968e-04 - val_mae: 0.0080
# Epoch 151/200
# 52/52 [==============================] - 0s 2ms/step - loss: 0.0014 - mae: 0.0257 - val_loss: 3.3725e-04 - val_mae: 0.0100
# Epoch 152/200
# 52/52 [==============================] - 0s 3ms/step - loss: 0.0014 - mae: 0.0262 - val_loss: 3.5364e-04 - val_mae: 0.0175
# Epoch 153/200
# 52/52 [==============================] - 0s 3ms/step - loss: 2.8435e-04 - mae: 0.0104 - val_loss: 4.4923e-05 - val_mae: 0.0038
# Epoch 154/200
# 52/52 [==============================] - 0s 3ms/step - loss: 2.3598e-04 - mae: 0.0099 - val_loss: 1.7832e-04 - val_mae: 0.0108
# Epoch 155/200
# 52/52 [==============================] - 0s 2ms/step - loss: 5.3648e-05 - mae: 0.0044 - val_loss: 9.5049e-05 - val_mae: 0.0065
# Epoch 156/200
# 52/52 [==============================] - 0s 3ms/step - loss: 4.4870e-05 - mae: 0.0047 - val_loss: 2.5672e-05 - val_mae: 0.0028
# Epoch 157/200
# 52/52 [==============================] - 0s 3ms/step - loss: 1.1083e-04 - mae: 0.0061 - val_loss: 6.3156e-05 - val_mae: 0.0056
# Epoch 158/200
# 52/52 [==============================] - 0s 3ms/step - loss: 8.7033e-05 - mae: 0.0057 - val_loss: 2.4667e-05 - val_mae: 0.0028
# Epoch 159/200
# 52/52 [==============================] - 0s 2ms/step - loss: 1.6382e-04 - mae: 0.0077 - val_loss: 4.7057e-04 - val_mae: 0.0186
# Epoch 160/200
# 52/52 [==============================] - 0s 3ms/step - loss: 6.0007e-05 - mae: 0.0047 - val_loss: 4.5881e-05 - val_mae: 0.0030
# Epoch 161/200
# 52/52 [==============================] - 0s 3ms/step - loss: 7.0441e-05 - mae: 0.0050 - val_loss: 8.6928e-05 - val_mae: 0.0078
# Epoch 162/200
# 52/52 [==============================] - 0s 3ms/step - loss: 9.8589e-05 - mae: 0.0057 - val_loss: 3.8599e-04 - val_mae: 0.0158
# Epoch 163/200
# 52/52 [==============================] - 0s 4ms/step - loss: 3.7530e-04 - mae: 0.0118 - val_loss: 0.0012 - val_mae: 0.0231
# Epoch 164/200
# 52/52 [==============================] - 0s 3ms/step - loss: 9.1514e-04 - mae: 0.0188 - val_loss: 0.0021 - val_mae: 0.0302
# Epoch 165/200
# 52/52 [==============================] - 0s 3ms/step - loss: 0.0012 - mae: 0.0238 - val_loss: 0.0017 - val_mae: 0.0387
# Epoch 166/200
# 52/52 [==============================] - 0s 3ms/step - loss: 7.3975e-04 - mae: 0.0196 - val_loss: 1.6391e-04 - val_mae: 0.0095
# Epoch 167/200
# 52/52 [==============================] - 0s 3ms/step - loss: 1.0802e-04 - mae: 0.0067 - val_loss: 7.8568e-05 - val_mae: 0.0074
# Epoch 168/200
# 52/52 [==============================] - 0s 3ms/step - loss: 8.1043e-05 - mae: 0.0059 - val_loss: 7.3388e-05 - val_mae: 0.0043
# Epoch 169/200
# 52/52 [==============================] - 0s 3ms/step - loss: 3.0313e-05 - mae: 0.0035 - val_loss: 3.9492e-05 - val_mae: 0.0035
# Epoch 170/200
# 52/52 [==============================] - 0s 3ms/step - loss: 5.3196e-05 - mae: 0.0051 - val_loss: 8.2449e-05 - val_mae: 0.0047
# Epoch 171/200
# 52/52 [==============================] - 0s 3ms/step - loss: 5.5250e-05 - mae: 0.0049 - val_loss: 6.3973e-05 - val_mae: 0.0049
# Epoch 172/200
# 52/52 [==============================] - 0s 3ms/step - loss: 5.5873e-05 - mae: 0.0050 - val_loss: 5.1948e-05 - val_mae: 0.0047
# Epoch 173/200
# 52/52 [==============================] - 0s 3ms/step - loss: 9.5577e-05 - mae: 0.0065 - val_loss: 2.6528e-04 - val_mae: 0.0106
# Epoch 174/200
# 52/52 [==============================] - 0s 3ms/step - loss: 2.5646e-04 - mae: 0.0108 - val_loss: 1.2404e-04 - val_mae: 0.0053
# Epoch 175/200
# 52/52 [==============================] - 0s 3ms/step - loss: 5.5579e-04 - mae: 0.0146 - val_loss: 7.6811e-04 - val_mae: 0.0096
# Epoch 176/200
# 52/52 [==============================] - 0s 3ms/step - loss: 2.8599e-04 - mae: 0.0112 - val_loss: 1.0235e-04 - val_mae: 0.0081
# Epoch 177/200
# 52/52 [==============================] - 0s 3ms/step - loss: 3.8123e-04 - mae: 0.0124 - val_loss: 7.5923e-04 - val_mae: 0.0213
# Epoch 178/200
# 52/52 [==============================] - 0s 3ms/step - loss: 0.0011 - mae: 0.0215 - val_loss: 0.0011 - val_mae: 0.0262
# Epoch 179/200
# 52/52 [==============================] - 0s 3ms/step - loss: 6.7720e-04 - mae: 0.0177 - val_loss: 3.9180e-04 - val_mae: 0.0146
# Epoch 180/200
# 52/52 [==============================] - 0s 3ms/step - loss: 1.3729e-04 - mae: 0.0078 - val_loss: 1.9491e-04 - val_mae: 0.0061
# Epoch 181/200
# 52/52 [==============================] - 0s 3ms/step - loss: 1.0591e-04 - mae: 0.0067 - val_loss: 1.4517e-04 - val_mae: 0.0080
# Epoch 182/200
# 52/52 [==============================] - 0s 3ms/step - loss: 7.1445e-05 - mae: 0.0060 - val_loss: 5.9710e-05 - val_mae: 0.0051
# Epoch 183/200
# 52/52 [==============================] - 0s 3ms/step - loss: 2.4693e-05 - mae: 0.0035 - val_loss: 3.4655e-05 - val_mae: 0.0028
# Epoch 184/200
# 52/52 [==============================] - 0s 3ms/step - loss: 3.1313e-05 - mae: 0.0035 - val_loss: 2.2844e-04 - val_mae: 0.0115
# Epoch 185/200
# 52/52 [==============================] - 0s 3ms/step - loss: 2.4128e-04 - mae: 0.0113 - val_loss: 1.2458e-04 - val_mae: 0.0047
# Epoch 186/200
# 52/52 [==============================] - 0s 5ms/step - loss: 1.9262e-04 - mae: 0.0088 - val_loss: 2.9276e-04 - val_mae: 0.0073
# Epoch 187/200
# 52/52 [==============================] - 0s 3ms/step - loss: 0.0018 - mae: 0.0277 - val_loss: 1.7766e-04 - val_mae: 0.0106
# Epoch 188/200
# 52/52 [==============================] - 0s 3ms/step - loss: 0.0012 - mae: 0.0232 - val_loss: 5.6880e-04 - val_mae: 0.0176
# Epoch 189/200
# 52/52 [==============================] - 0s 3ms/step - loss: 3.3703e-04 - mae: 0.0122 - val_loss: 8.2394e-05 - val_mae: 0.0069
# Epoch 190/200
# 52/52 [==============================] - 0s 4ms/step - loss: 1.7398e-04 - mae: 0.0082 - val_loss: 9.9101e-05 - val_mae: 0.0050
# Epoch 191/200
# 52/52 [==============================] - 0s 3ms/step - loss: 9.9041e-05 - mae: 0.0060 - val_loss: 9.7881e-05 - val_mae: 0.0072
# Epoch 192/200
# 52/52 [==============================] - 0s 3ms/step - loss: 2.3874e-04 - mae: 0.0097 - val_loss: 3.1758e-04 - val_mae: 0.0163
# Epoch 193/200
# 52/52 [==============================] - 0s 3ms/step - loss: 4.1309e-04 - mae: 0.0133 - val_loss: 1.9110e-04 - val_mae: 0.0119
# Epoch 194/200
# 52/52 [==============================] - 0s 3ms/step - loss: 0.0012 - mae: 0.0214 - val_loss: 2.8117e-04 - val_mae: 0.0110
# Epoch 195/200
# 52/52 [==============================] - 0s 3ms/step - loss: 3.0367e-04 - mae: 0.0111 - val_loss: 1.9407e-04 - val_mae: 0.0109
# Epoch 196/200
# 52/52 [==============================] - 0s 3ms/step - loss: 9.2203e-04 - mae: 0.0208 - val_loss: 8.2417e-04 - val_mae: 0.0209
# Epoch 197/200
# 52/52 [==============================] - 0s 3ms/step - loss: 3.4280e-04 - mae: 0.0128 - val_loss: 1.4081e-04 - val_mae: 0.0084
# Epoch 198/200
# 52/52 [==============================] - 0s 3ms/step - loss: 5.9736e-04 - mae: 0.0153 - val_loss: 0.0012 - val_mae: 0.0280
# Epoch 199/200
# 52/52 [==============================] - 0s 3ms/step - loss: 3.4861e-04 - mae: 0.0132 - val_loss: 2.3491e-04 - val_mae: 0.0097
# Epoch 200/200
# 52/52 [==============================] - 0s 3ms/step - loss: 9.5447e-05 - mae: 0.0067 - val_loss: 4.3879e-05 - val_mae: 0.0039
# Model saved as mosfet_model_6V.h5
# 7/7 [==============================] - 0s 2ms/step - loss: 4.3879e-05 - mae: 0.0039
# Test MAE: 0.003877

# %%
import numpy as np
import matplotlib.pyplot as plt
from tensorflow.keras.models import load_model
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
from sklearn.preprocessing import MinMaxScaler

# Load the trained model
model = load_model("/mnt/data/mosfet_model_6V.h5")

# Prepare test data again
VGS_values = np.arange(0, 3.4, 0.2)  # VGS from 0V to 3.2V, step -0.2V
num_VGS = len(VGS_values)
num_points_per_sweep = len(VDS) // num_VGS
VDS_reshaped = VDS[:num_points_per_sweep]  # First VDS sweep reference

# Generate input data for evaluation
X_test = np.array([[VGS, vds] for VGS in VGS_values for vds in VDS_reshaped])

# Normalize the test data using the same scalers
scaler_X = MinMaxScaler()
scaler_y = MinMaxScaler()
scaler_X.fit(np.array([[min(VGS_values), 0], [max(VGS_values), max(VDS)]]))  # Fit using known dataset range
scaler_y.fit(ID.reshape(-1, 1))  # Fit output scaler using ID range

X_test_scaled = scaler_X.transform(X_test)

# Predict ID
ID_pred_scaled = model.predict(X_test_scaled)
ID_pred = scaler_y.inverse_transform(ID_pred_scaled)  # Convert back to real scale

# Extract actual values from dataset
ID_actual = ID.reshape(num_VGS, num_points_per_sweep)
ID_predicted = ID_pred.reshape(num_VGS, num_points_per_sweep)

# Compute performance metrics
mae = mean_absolute_error(ID_actual.flatten(), ID_predicted.flatten())
mse = mean_squared_error(ID_actual.flatten(), ID_predicted.flatten())
rmse = np.sqrt(mse)
r2 = r2_score(ID_actual.flatten(), ID_predicted.flatten())

# Print results
print(f"Test MAE: {mae:.6e}")
print(f"Test MSE: {mse:.6e}")
print(f"Test RMSE: {rmse:.6e}")
print(f"Test R² Score: {r2:.6f}")

# Plot actual vs predicted values
plt.figure(figsize=(8, 6))
plt.scatter(ID_actual.flatten(), ID_predicted.flatten(), alpha=0.5, label="Predictions")
plt.plot([min(ID_actual.flatten()), max(ID_actual.flatten())], 
         [min(ID_actual.flatten()), max(ID_actual.flatten())], 'r', linestyle='dashed', label="Ideal Fit")
plt.xlabel("Actual ID (A)")
plt.ylabel("Predicted ID (A)")
plt.title("Neural Network Predictions vs Actual ID")
plt.legend()
plt.grid(True)
plt.show()
# Out:
# 33/33 [==============================] - 0s 1ms/step
# Test MAE: 1.400166e-05
# Test MSE: 5.719291e-10
# Test RMSE: 2.391504e-05
# Test R² Score: 0.998940

# %%
import numpy as np
import matplotlib.pyplot as plt

# Load the dataset
file_path = "Ouput 0-6V Gate 0-3.2V Step -0.2.txt"  # Change this if needed
data = np.loadtxt(file_path, usecols=(0, 1))  # Ignore third column

# Extract VDS and ID
VDS = data[:, 0]  # First column is VDS
ID = data[:, 1]  # Second column is ID

# Define VGS values based on the known step size in the dataset
VGS_values = np.arange(0, 3.4, 0.2)  # From 0V to 3.2V in steps of 0.2V
num_VGS = len(VGS_values)

# Compute number of data points per VGS sweep
num_points_per_sweep = len(VDS) // num_VGS  # Ensure correct reshaping

# Reshape data for plotting
VDS_reshaped = VDS[:num_points_per_sweep]  # Take first VDS sweep as reference
ID_reshaped = ID.reshape(num_VGS, num_points_per_sweep)

# Plot the output characteristics
plt.figure(figsize=(8, 6))
colors = plt.cm.viridis(np.linspace(0, 1, num_VGS))  # Different colors for different VGS

for i, VGS in enumerate(VGS_values):
    plt.plot(VDS_reshaped, ID_reshaped[i, :], color=colors[i], label=f"VGS = {VGS:.1f} V")

plt.xlabel("VDS (V)")
plt.ylabel("ID (A)")
plt.title("MOSFET Output Characteristics")
plt.legend()
plt.grid(True)
plt.show()
